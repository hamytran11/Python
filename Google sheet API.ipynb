# %%
pip install gspread oauth2client pandas mysql-connector-python pandasql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
import pandas as pd

# %%
# Ủy quyền bằng cách sử dụng file JSON credentials
gs = gspread.service_account(filename="cre.json")

# Mở Google Sheet bằng khóa
sht = gs.open_by_key("1716aQ1XqHDiHB4LHSClVYglY0Cgf60TVJ7RYjqlwsOM")

# Lấy toàn bộ giá trị từ trang đầu tiên của Google Sheet
all_values = sht.sheet1.get_all_values()

# # In dữ liệu
# for row in all_values:
#     print(row)

df = pd.DataFrame(all_values)
df
# Out:
#                     0        1      2                     3         4   \
# 0      Date livestream  Weekday  Month                 Store     Brand
# 1           01/06/2024    Thứ 7      6  P&G VIETNAM - TIKTOK       P&G
# 2           01/06/2024    Thứ 7      6       ELIXIR - TIKTOK    ELIXIR
# 3           01/06/2024    Thứ 7      6     DPROGRAM - TIKTOK  DPROGRAM
# 4           01/06/2024    Thứ 7      6      APTAMIL - TIKTOK   APTAMIL
# ...                ...      ...    ...                   ...       ...
# 10195
# 10196
# 10197
# 10198
# 10199
#
#              5               6                7              8         9   \
# 0      Platform     Group brand  Type of session      Time slot  Duration
# 1        TIKTOK             P&G                   09:00 - 11:00         2
# 2        TIKTOK  SHISEIDO COSME                   11:00 - 13:00         2
# 3        TIKTOK  SHISEIDO COSME                   11:00 - 13:00         2
# ...

# %%
# Mở Google Sheet
sht = gs.open_by_key("18jlxPPH4xeveftHxa2wj3_HBiUvMlT2MoibT76N89RU")

# Lấy toàn bộ giá trị từ trang đầu tiên của Google Sheet
all_values = sht.sheet1.get_all_values()

# # In dữ liệu
df2 = pd.DataFrame(all_values)
df2
# Out:
#                    0        1      2                           3   \
# 0     Date livestream  Weekday  Month                       Store
# 1          02/01/2024    Thứ 3      1       LOREAL PARIS - TIKTOK
# 2          02/01/2024    Thứ 3      1         MAYBELLINE - TIKTOK
# 3          02/01/2024    Thứ 3      1           CETAPHIL - TIKTOK
# 4          02/01/2024    Thứ 3      1             MOLFIX - TIKTOK
# ...               ...      ...    ...                         ...
# 5348       31/05/2024    Thứ 6      5         BLACKMORES - TIKTOK
# 5349       31/05/2024    Thứ 6      5              NIVEA - TIKTOK
# 5350       31/05/2024    Thứ 6      5  JOHNSON & JOHNSON - TIKTOK
# 5351       31/05/2024    Thứ 6      5             MOLFIX - TIKTOK
# 5352       25/05/2024    Thứ 7      5              OBAGI - TIKTOK
#
#                      4         5                  6                7   \
# 0                 Brand  Platform        Group brand  Type of session
# ...

# %%
#comnine 2 bảng
df_combined = pd.concat([df,df2],ignore_index=True)
df_combined
# Out:
#                     0        1      2                           3   \
# 0      Date livestream  Weekday  Month                       Store
# 1           01/06/2024    Thứ 7      6        P&G VIETNAM - TIKTOK
# 2           01/06/2024    Thứ 7      6             ELIXIR - TIKTOK
# 3           01/06/2024    Thứ 7      6           DPROGRAM - TIKTOK
# 4           01/06/2024    Thứ 7      6            APTAMIL - TIKTOK
# ...                ...      ...    ...                         ...
# 15548       31/05/2024    Thứ 6      5         BLACKMORES - TIKTOK
# 15549       31/05/2024    Thứ 6      5              NIVEA - TIKTOK
# 15550       31/05/2024    Thứ 6      5  JOHNSON & JOHNSON - TIKTOK
# 15551       31/05/2024    Thứ 6      5             MOLFIX - TIKTOK
# 15552       25/05/2024    Thứ 7      5              OBAGI - TIKTOK
#
#                       4         5                  6                7   \
# 0                  Brand  Platform        Group brand  Type of session
# ...

# %%
# Sử dụng dòng đầu tiên làm tên cột
df_combined.columns = df_combined.iloc[0]
df_combined = df_combined[1:]

# Reset
df_combined.reset_index(drop=True, inplace=True)
df_combined
# Out:
# 0     Date livestream Weekday Month                       Store  \
# 0          01/06/2024   Thứ 7     6        P&G VIETNAM - TIKTOK
# 1          01/06/2024   Thứ 7     6             ELIXIR - TIKTOK
# 2          01/06/2024   Thứ 7     6           DPROGRAM - TIKTOK
# 3          01/06/2024   Thứ 7     6            APTAMIL - TIKTOK
# 4          01/06/2024   Thứ 7     6        P&G VIETNAM - TIKTOK
# ...               ...     ...   ...                         ...
# 15547      31/05/2024   Thứ 6     5         BLACKMORES - TIKTOK
# 15548      31/05/2024   Thứ 6     5              NIVEA - TIKTOK
# 15549      31/05/2024   Thứ 6     5  JOHNSON & JOHNSON - TIKTOK
# 15550      31/05/2024   Thứ 6     5             MOLFIX - TIKTOK
# 15551      25/05/2024   Thứ 7     5              OBAGI - TIKTOK
#
# 0                  Brand Platform        Group brand Type of session  \
# 0                    P&G   TIKTOK                P&G
# 1                 ELIXIR   TIKTOK     SHISEIDO COSME
# ...

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15552 entries, 0 to 15551
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date livestream  15552 non-null  object
#  1   Weekday          15552 non-null  object
#  2   Month            15552 non-null  object
#  3   Store            15552 non-null  object
#  4   Brand            15552 non-null  object
#  5   Platform         15552 non-null  object
#  6   Group brand      15552 non-null  object
#  7   Type of session  15552 non-null  object
#  8   Time slot        15552 non-null  object
#  9   Duration         15552 non-null  object
#  10  Session          15552 non-null  object
#  11  Status           15552 non-null  object
#  12  Talent 1         15552 non-null  object
#  13  Talent 2         15552 non-null  object
#  14  Coordinator 1    15552 non-null  object
#  15  Coordinator 2    15552 non-null  object
# ...

# %%
# Loại bỏ các dòng có "Status" là "Cancel"
df_combined = df_combined[df_combined["Status"] != "Cancel"]

# %%
df_combined.to_csv("combined_output.csv", index=False)

# %%
df_combined.tail(5)
# Out:
# 0     Date livestream Weekday Month                       Store  \
# 15547      31/05/2024   Thứ 6     5         BLACKMORES - TIKTOK
# 15548      31/05/2024   Thứ 6     5              NIVEA - TIKTOK
# 15549      31/05/2024   Thứ 6     5  JOHNSON & JOHNSON - TIKTOK
# 15550      31/05/2024   Thứ 6     5             MOLFIX - TIKTOK
# 15551      25/05/2024   Thứ 7     5              OBAGI - TIKTOK
#
# 0                  Brand Platform        Group brand Type of session  \
# 15547         BLACKMORES   TIKTOK         BLACKMORES
# 15548              NIVEA   TIKTOK              NIVEA
# 15549  JOHNSON & JOHNSON   TIKTOK  JOHNSON & JOHNSON
# 15550             MOLFIX   TIKTOK              HAYAT
# 15551              OBAGI   TIKTOK              OBAGI
#
# 0          Time slot Duration  ... Address  Device  \
# 15547  20:00 - 22:00        2  ...          Camera
# 15548  20:30 - 22:30        2  ...          Camera
# 15549  21:00 - 23:00        2  ...           Phone
# ...

# %%
#transpose
df_combined.T
# Out:
#                                              0      \
# 0
# Date livestream                         01/06/2024
# Weekday                                      Thứ 7
# Month                                            6
# Store                         P&G VIETNAM - TIKTOK
# Brand                                          P&G
# Platform                                    TIKTOK
# Group brand                                    P&G
# Type of session
# Time slot                            09:00 - 11:00
# Duration                                         2
# Session                                          1
# Status                                        Done
# Talent 1                             Host external
# Talent 2                                   Anh Thư
# Coordinator 1                              Nhật Lê
# Coordinator 2
# PIC_tech                                       Đạt
# Studio                              Onpoint Studio
# Studio/Room                               Stu. 206
# ...
